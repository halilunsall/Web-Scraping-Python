# %%
import pandas as pd
import numpy as np
import warnings
pd.options.display.max_colwidth = 50
pd.options.display.max_columns = None
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Books_Scrap.csv')

# %%
df.head()
# Out:
#                               0                          1                 2  \
# 0       Gece Yarısı Kütüphanesi                  Matt Haig  DOMİNGO YAYINEVİ
# 1  Sular Üstünde Gökler Altında           Kaan Murat Yanık   KETEBE YAYINEVİ
# 2     Şeker Portakalı (Ciltsiz)  Jose Mauro De Vasconcelos     CAN YAYINLARI
# 3        İnsanlığımı Yitirirken                Osamu Dazai  İTHAKİ YAYINLARI
# 4                           Dad        Selahattin Demirtaş  DİPNOT YAYINLARI
#
#                                                    3  \
# 0  42 DİLE ÇEVRİLEN ULUSLARARASI ÇOKSATAN 2020 GO...
# 1  Amerika, aşk ve saflık yeniden keşfedilebilir ...
# 2  “Ne güzel bir şeker portakalı fidanıymış bu! H...
# 3  “… Ben hâlâ, ölmeyi bile becerememiş utanmaz, ...
# 4  Başlangıçta koku biraz zorluyordu. Kanıksadım ...
#
#                                                    4  5        6  \
# 0  Çevirmen:\n Kıvanç Güney\n\n\nYayın Tarihi:\n2...  5  932.000
# 1  Yayın Tarihi:\n07.03.2023\n\n\nISBN:\n97862569...  5   11.000
# 2  Çevirmen:\n Emrah İmre\n\n\nKapak:\n Utku Loml...  5   10.216
# 3  Çevirmen:\n Peren Ercan\n\n\nYayın Tarihi:\n28...  4   55.000
# 4  Yayın Tarihi:\n09.03.2023\n\n\nISBN:\n97860571...  4    2.000
#
#                                                    7        8       9
# 0  \n\n\n\n\n                    Okuyacağım      ...   65.825   53,91
# 1  \n\n\n\n\n                    Okuyacağım      ...    1.502   68,06
# 2  \n\n\n\n\n                    Okuyacağım      ...  278.820   48,75
# 3  \n\n\n\n\n                    Okuyacağım      ...    4.726   22,60
# 4  \n\n\n\n\n                    Okuyacağım      ...  534.000   49,50

# %%
df.rename(columns={'0':'name', '1':'writer', '2':'publisher', '3':'about', '4':'informations', '5':'rate', '6':'comment', '7':'read_status', '8':'sales', '9':'price'}, inplace=True)

# %%
col_list = []
for i in df.informations:
    col = i.replace(':','').split('\n')[::4]
    for ii in col:
        if ii not in col_list:
            col_list.append(ii)
for i in col_list:
    df[i] = np.nan
for i in range(len(df)):
    title = df.informations[i].replace(':','').split('\n')[::4]
    index = df.informations[i].replace(':','').split('\n')[1::4]
    for ii in range(len(title)):
        df[title[ii]][i] = index[ii]
df.drop(columns='informations', axis=1, inplace=True)

# %%
df.comment = df.comment.astype('str')
df.comment = df.comment.apply(lambda x: x.replace('.0','').replace('.',''))
df.comment = df.comment.astype('int')

# %%
df['Okuyacağım'] = np.nan
df['Okuyorum'] = np.nan
df['Okudum'] = np.nan

for i in range(len(df)):
    locs = df.read_status[i].strip().split()
    df[locs[0]][i] = locs[1]
    df[locs[2]][i] = locs[3]
    df[locs[4]][i] = locs[5]
df.drop(columns='read_status', axis=1, inplace=True)

# %%
df.sales = df.sales.astype('str')
df.sales = df.sales.apply(lambda x: x.replace('.0','').replace('.',''))
df.sales = df.sales.astype('int')

# %%
df.price = df.price.apply(lambda x: x.strip().replace(',','.'))
df.price = df.price.astype('float')

# %%
df.rename(columns={'Çevirmen':'translator','Yayın Tarihi':'publish_date','Orijinal Adı':'original_name','ISBN':'isbn','Dil':'language','Sayfa Sayısı':'page','Cilt Tipi':'volume_type','Kağıt Cinsi':'paper_type','Boyut':'size','Okuyacağım':'will_read','Okuyorum':'reading','Okudum':'have_read'}, inplace=True)

# %%
df.drop(columns=['Kapak','Editor','Çizer','Diğer Özellik','Derleyici'], inplace=True)

# %%
for i in df[df.translator.isnull() == True].index:
    df.translator[i] = df.writer[i]
for i in df[df.original_name.isnull() == True].index:
    df.original_name[i] = df.name[i]
df['size'].fillna('13.5 x 21 cm', inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isbn = df.isbn.astype('int64')

# %%
df.page = df.page.astype('int')

# %%
df.will_read = df.will_read.apply(lambda x: x.replace('.',''))
df.will_read = df.will_read.astype('int')
df.reading = df.reading.apply(lambda x: x.replace('.',''))
df.reading = df.reading.astype('int')
df.have_read = df.have_read.apply(lambda x: x.replace('.',''))
df.have_read = df.have_read.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482 entries, 0 to 484
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           482 non-null    object
#  1   writer         482 non-null    object
#  2   publisher      482 non-null    object
#  3   about          482 non-null    object
#  4   rate           482 non-null    int64
#  5   comment        482 non-null    int32
#  6   sales          482 non-null    int32
#  7   price          482 non-null    float64
#  8   translator     482 non-null    object
#  9   publish_date   482 non-null    object
#  10  original_name  482 non-null    object
#  11  isbn           482 non-null    int64
#  12  language       482 non-null    object
#  13  page           482 non-null    int32
#  14  volume_type    482 non-null    object
#  15  paper_type     482 non-null    object
#  16  size           482 non-null    object
#  17  will_read      482 non-null    int32
#  18  reading        482 non-null    int32
#  19  have_read      482 non-null    int32
# dtypes: float64(1), int32(6), int64(2), object(11)
# memory usage: 67.8+ KB

# %%
df.head()
# Out:
#                            name                     writer         publisher  \
# 0       Gece Yarısı Kütüphanesi                  Matt Haig  DOMİNGO YAYINEVİ
# 1  Sular Üstünde Gökler Altında           Kaan Murat Yanık   KETEBE YAYINEVİ
# 2     Şeker Portakalı (Ciltsiz)  Jose Mauro De Vasconcelos     CAN YAYINLARI
# 3        İnsanlığımı Yitirirken                Osamu Dazai  İTHAKİ YAYINLARI
# 4                           Dad        Selahattin Demirtaş  DİPNOT YAYINLARI
#
#                                                about  rate  comment  sales  \
# 0  42 DİLE ÇEVRİLEN ULUSLARARASI ÇOKSATAN 2020 GO...     5      932  65825
# 1  Amerika, aşk ve saflık yeniden keşfedilebilir ...     5       11   1502
# 2  “Ne güzel bir şeker portakalı fidanıymış bu! H...     5    10216  27882
# 3  “… Ben hâlâ, ölmeyi bile becerememiş utanmaz, ...     4       55   4726
# 4  Başlangıçta koku biraz zorluyordu. Kanıksadım ...     4        2    534
#
#    price           translator publish_date                 original_name  \
# 0  53.91         Kıvanç Güney   23.02.2022          The Midnight Library
# 1  68.06     Kaan Murat Yanık   07.03.2023  Sular Üstünde Gökler Altında
# 2  48.75           Emrah İmre   06.09.2019      O Meu Pé de Laranja Lima
# 3  22.60          Peren Ercan   28.12.2022         Ningen Şikkaku (人間失格)
# 4  49.50  Selahattin Demirtaş   09.03.2023                           Dad
#
#             isbn language  page   volume_type    paper_type            size  \
# 0  9786051981833   TÜRKÇE   283  Karton Kapak  Kitap Kağıdı      14 x 21 cm
# 1  9786256999749   TÜRKÇE   352  Karton Kapak  Kitap Kağıdı    13.5 x 21 cm
# 2  9789750738609   TÜRKÇE   182  Karton Kapak  Kitap Kağıdı  12.5 x 19.5 cm
# 3  9786258401479   TÜRKÇE   128  Karton Kapak  Kitap Kağıdı  12.5 x 19.5 cm
# 4  9786057197948   TÜRKÇE   152  Karton Kapak  Kitap Kağıdı    13 x 19.5 cm
#
#    will_read  reading  have_read
# 0       3238      420       3414
# 1         99       11         18
# 2       8026     1164      27050
# 3        266       22        178
# 4         51        3         10
